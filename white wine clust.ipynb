# %%
# Импорт библиотек для работы с таблицами данных
import numpy as np
import pandas as pd

# Для визуализации данных
from matplotlib import pyplot as plt

# Библиотеки для масштабирования данных, кластеризации, классификации и регрессии
from sklearn.model_selection import train_test_split

from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans

from sklearn.ensemble import ExtraTreesRegressor

from sklearn.decomposition import PCA

from sklearn.pipeline import Pipeline

from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA

# %%
# Считываем данные по белому вину
original_data = pd.read_csv("./winequality-white.csv", sep=";")

# %%
# Всего там 11 столбцов признаков, все непрерывные, + столбец целевых значений
original_data.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.0              0.27         0.36           20.70      0.045
# 1             6.3              0.30         0.34            1.60      0.049
# 2             8.1              0.28         0.40            6.90      0.050
# 3             7.2              0.23         0.32            8.50      0.058
# 4             7.2              0.23         0.32            8.50      0.058
# 5             8.1              0.28         0.40            6.90      0.050
# 6             6.2              0.32         0.16            7.00      0.045
# 7             7.0              0.27         0.36           20.70      0.045
# 8             6.3              0.30         0.34            1.60      0.049
# 9             8.1              0.22         0.43            1.50      0.044
# 10            8.1              0.27         0.41            1.45      0.033
# 11            8.6              0.23         0.40            4.20      0.035
# 12            7.9              0.18         0.37            1.20      0.040
# 13            6.6              0.16         0.40            1.50      0.044
# 14            8.3              0.42         0.62           19.25      0.040
# 15            6.6              0.17         0.38            1.50      0.032
# 16            6.3              0.48         0.04            1.10      0.046
# 17            6.2              0.66         0.48            1.20      0.029
# 18            7.4              0.34         0.42            1.10      0.033
# 19            6.5              0.31         0.14            7.50      0.044
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  45.0                 170.0   1.0010  3.00       0.45
# 1                  14.0                 132.0   0.9940  3.30       0.49
# 2                  30.0                  97.0   0.9951  3.26       0.44
# 3                  47.0                 186.0   0.9956  3.19       0.40
# 4                  47.0                 186.0   0.9956  3.19       0.40
# 5                  30.0                  97.0   0.9951  3.26       0.44
# 6                  30.0                 136.0   0.9949  3.18       0.47
# 7                  45.0                 170.0   1.0010  3.00       0.45
# 8                  14.0                 132.0   0.9940  3.30       0.49
# 9                  28.0                 129.0   0.9938  3.22       0.45
# 10                 11.0                  63.0   0.9908  2.99       0.56
# 11                 17.0                 109.0   0.9947  3.14       0.53
# 12                 16.0                  75.0   0.9920  3.18       0.63
# 13                 48.0                 143.0   0.9912  3.54       0.52
# 14                 41.0                 172.0   1.0002  2.98       0.67
# 15                 28.0                 112.0   0.9914  3.25       0.55
# 16                 30.0                  99.0   0.9928  3.24       0.36
# 17                 29.0                  75.0   0.9892  3.33       0.39
# 18                 17.0                 171.0   0.9917  3.12       0.53
# 19                 34.0                 133.0   0.9955  3.22       0.50
#
#     alcohol  quality
# 0       8.8        6
# 1       9.5        6
# 2      10.1        6
# 3       9.9        6
# 4       9.9        6
# 5      10.1        6
# 6       9.6        6
# 7       8.8        6
# 8       9.5        6
# 9      11.0        6
# 10     12.0        5
# 11      9.7        5
# 12     10.8        5
# 13     12.4        7
# 14      9.7        5
# 15     11.4        7
# 16      9.6        6
# 17     12.8        8
# 18     11.3        6
# 19      9.5        5

# %%
# Отбрасываем столбце значений качества в отдельную переменную, остальные
# признаки в переменную X - по ней и кластеризуем
data = original_data.copy()
X = data.drop("quality", axis="columns")
y = data.quality

# %%
# Определяем качества вина с помощью случайного леса. Это преследует две цели
# - проверить, будут ли кластеры более чистыми с точки зрения предсказанных значений
#   качества, чем с точки зрения истинных
# - Отобрать несколько наиболее важных признаков и посмотреть, что будет, если кластеризовать
#   уже по ним
(X_train, X_test, y_train, y_test) = train_test_split(X, y, random_state=0, stratify=y)
reg = ExtraTreesRegressor(max_depth=5, random_state=0)
reg.fit(X_train, y_train)
print(reg.score(X_train, y_train))
print(reg.score(X_test, y_test))
y_pred = reg.predict(X)
# Out:
# 0.3291828202724755
# 0.3247875187576794

# %%
# Смотрим, какие признаки для этой модели наиболее важны
pd.Series(reg.feature_importances_, index=X.columns)
# Out:
# fixed acidity           0.010160
# volatile acidity        0.155223
# citric acid             0.025320
# residual sugar          0.012630
# chlorides               0.031896
# free sulfur dioxide     0.086152
# total sulfur dioxide    0.028227
# density                 0.045817
# pH                      0.009071
# sulphates               0.009087
# alcohol                 0.586417
# dtype: float64

# %%
# Отбираем 3 наиболее важных
X2 = data[["alcohol", "volatile acidity", "free sulfur dioxide"]]

# %%
# Готовим таблицу для хранения данных о чистоте кластеров
# Для каждого метода кластеризации в этой таблице будет
# - Признак обучения с учителем, что означает обучения на подмножестве
#   признаков, отобранных как самые важные для модели с учителем.
#   Такие кластеры, к сожалению, нельзя назвать полученными полностью
#   без учителя
# - Количество кластеров
# - Максимальный из размеров кластеров.
# - Минимальный из размеров кластеров
# - Максимальное качество кластера. То есть, для каждого кластера
#   берется среднее качество вина, попавшего в этот кластер, а
#   потом берется максимум по всем кластерам
# - Минимальное качество кластера. То есть, для каждого кластера
#   берется среднее качество вина, попавшего в этот кластер, а
#   потом берется минимум по всем кластерам
# - Максимальное предсказанное качество кластера. То есть, для каждого кластера
#   берется среднее предсказанное случайным лесом качество вина, попавшего в
#   этот кластер, а потом берется максимум по всем кластерам
# - Минимальное предсказанное качество кластера. То есть, для каждого кластера
#   берется среднее предсказанное случайным лесом качество вина, попавшего в
#   этот кластер, а потом берется минимум по всем кластерам
# Последние два значения помогут определитт, что кластеризация определяет
# лучше - кластеры однородные в плане истинного качетва вина или в плане
# качества, которое предсказывает обученная с учителем модель
def createScoreboard():
    return pd.DataFrame(
        columns=[
            "С учителем",
            "Количество кластеров",
            "Максимальный размер кластера",
            "Минимальный размер кластера",
            "Максимальное среднее качество по кластеру",
            "Минимальное среднее качество по кластеру",
            "Максимальное предсказанное среднее качество по кластеру",
            "Минимальное предсказанное среднее качество по кластеру",
        ]
    )

REGRESSION_CLUSTER_RESULTS = createScoreboard()

# А теперь - функция, предназначенная для добавления строк в эту
# таблицу
def tryClusterer(description, reg, clusters, results, supervised=False):
    """
    На основании разбиения данных на кластеры запоминает в таблице results
    метрики качества этого разбиения
    
    Параметры
    ---------
    description: str
        Описание метода бинарной кластеризации
    
    reg: sklearn.BaseEstimator
        Регрессор, с предсказаниями которого сравниваем кластеры

    clusters: array-like, shape=(len(X))
        Массив с метками кластеров, каждый элемент соответствует строке
        исходных данных

    results:
        Таблица, в которую записывается результат, формат соответствует
        таблице REGRESSION_CLUSTER_RESULTS

    supervised: bool, по умолучанию False
        Если True, то это кластеры, посторенные на признаках, отобранных
        с помощью модели с учителем
    """
    labels = set(clusters)
    clusters = pd.Series(clusters, index=data.index)
    # В дополнение к истинным значениям качества, смотрим как будут
    # распределены предсказанные случайным лесом
    y_pred = pd.Series(reg.predict(X), index=data.index)
    results.loc[description, "С учителем"] = supervised
    results.loc[description, "Количество кластеров"] = len(labels)
    min_size = None
    max_size = None
    min_quality = None
    max_quality = None
    min_predicted = None
    max_predicted = None
    for label in labels:
        # Для каждого кластера определяем его размер, среднее качество
        # вина в нем и среднее предсказанное случайным лесом качество.
        size = len(data.loc[clusters == label])
        quality = data.loc[clusters == label].quality.mean()
        predicted = y_pred.loc[clusters == label].mean()
        # Потом для каждого из этих значений заносим в таблицу эго
        # максимум и минимум по всем кластерам
        if min_size is None:
            min_size = size
        else:
            min_size = min(min_size, size)
        if max_size is None:
            max_size = size
        else:
            max_size = max(max_size, size)
        if min_quality is None:
            min_quality = quality
        else:
            min_quality = min(min_quality, quality)
        if max_quality is None:
            max_quality = quality
        else:
            max_quality = max(max_quality, quality)
        if min_predicted is None:
            min_predicted = predicted
        else:
            min_predicted = min(min_predicted, predicted)
        if max_predicted is None:
            max_predicted = predicted
        else:
            max_predicted = max(max_predicted, predicted)
    results.loc[description, "Максимальный размер кластера"] = max_size
    results.loc[description, "Минимальный размер кластера"] = min_size
    results.loc[description, "Максимальное среднее качество по кластеру"] = max_quality
    results.loc[description, "Минимальное среднее качество по кластеру"] = min_quality
    results.loc[description, "Максимальное предсказанное среднее качество по кластеру"] = max_predicted
    results.loc[description, "Минимальное предсказанное среднее качество по кластеру"] = min_predicted

# %%
# Если бы вино идеально разделилось на кластеры с хорошим и плохим поровну,
# каким было бы среднее качество хорошего вина, и каким среднее качество
# плохого
tryClusterer(
    "Идеальный вариант",
    reg,
    y >= y.median(),
    REGRESSION_CLUSTER_RESULTS,
    True
)
tryClusterer(
    "Идеальный вариант для предсказанного качества",
    reg,
    y_pred >= pd.Series(y_pred).median(),
    REGRESSION_CLUSTER_RESULTS,
    True
)
# Делим на 2, 3 или 4 кластера метдом K средних
tryClusterer(
    "K-средних/2 класса",
    reg,
    KMeans(n_clusters=2).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
tryClusterer(
    "K-средних/3 класса",
    reg,
    KMeans(n_clusters=3).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
tryClusterer(
    "K-средних/4 класса",
    reg,
    KMeans(n_clusters=4).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
# Используем предварительное масштабирование данных, также метод K-средних
tryClusterer(
    "K-средних/2 класса/масштабирование",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', KMeans(n_clusters=2))
        ]
    ).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
tryClusterer(
    "K-средних/3 класса/масштабирование",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', KMeans(n_clusters=4))
        ]
    ).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
tryClusterer(
    "K-средних/3 класса/масштабирование",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', KMeans(n_clusters=4))
        ]
    ).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
# Делим на 2, 3 или 4 кластера метдом агломеративной кластеризации
tryClusterer(
    "Агломеративная/2 класса",
    reg,
    AgglomerativeClustering(n_clusters=2).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
tryClusterer(
    "Агломеративная/3 класса",
    reg,
    AgglomerativeClustering(n_clusters=3).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
tryClusterer(
    "Агломеративная/4 класса",
    reg,
    AgglomerativeClustering(n_clusters=4).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
# Используем предварительное масштабирование данных, также метод агломеративной кластеризации
tryClusterer(
    "Агломеративная/2 класса/масштабирование",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', AgglomerativeClustering(n_clusters=2))
        ]
    ).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
tryClusterer(
    "Агломеративная/3 класса/масштабирование",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', AgglomerativeClustering(n_clusters=4))
        ]
    ).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
tryClusterer(
    "Агломеративная/3 класса/масштабирование",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', AgglomerativeClustering(n_clusters=4))
        ]
    ).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
# Агломеративная кластеризация с пороговым значением размера кластера
tryClusterer(
    "Агломеративная/Порог 25/масштабирование",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', AgglomerativeClustering(n_clusters=None, distance_threshold=25))
        ]
    ).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
tryClusterer(
    "Агломеративная/Порог 50/масштабирование",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', AgglomerativeClustering(n_clusters=None, distance_threshold=50))
        ]
    ).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)

# %%
# Далее все то же самое, но используем только признаки, отобранные
# моделю с учителем. Три наиболее важных 
# Делим на 2, 3 или 4 кластера метдом K средних
tryClusterer(
    "K-средних/2 класса/3 признака",
    reg,
    KMeans(n_clusters=2).fit_predict(X2),
    REGRESSION_CLUSTER_RESULTS,
    supervised=True
)
tryClusterer(
    "K-средних/3 класса/3 признака",
    reg,
    KMeans(n_clusters=3).fit_predict(X2),
    REGRESSION_CLUSTER_RESULTS,
    supervised=True
)
tryClusterer(
    "K-средних/4 класса/3 признака",
    reg,
    KMeans(n_clusters=4).fit_predict(X2),
    REGRESSION_CLUSTER_RESULTS,
    supervised=True
)
# Используем предварительное масштабирование данных, также метод K-средних
tryClusterer(
    "K-средних/2 класса/масштабирование/3 признака",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', KMeans(n_clusters=2))
        ]
    ).fit_predict(X2),
    REGRESSION_CLUSTER_RESULTS,
    supervised=True
)
tryClusterer(
    "K-средних/3 класса/масштабирование/3 признака",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', KMeans(n_clusters=4))
        ]
    ).fit_predict(X2),
    REGRESSION_CLUSTER_RESULTS,
    supervised=True
)
tryClusterer(
    "K-средних/3 класса/масштабирование/3 признака",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', KMeans(n_clusters=4))
        ]
    ).fit_predict(X2),
    REGRESSION_CLUSTER_RESULTS,
    supervised=True
)
# Делим на 2, 3 или 4 кластера метдом агломеративной кластеризации
tryClusterer(
    "Агломеративная/2 класса/3 признака",
    reg,
    AgglomerativeClustering(n_clusters=2).fit_predict(X2),
    REGRESSION_CLUSTER_RESULTS,
    supervised=True
)
tryClusterer(
    "Агломеративная/3 класса/3 признака",
    reg,
    AgglomerativeClustering(n_clusters=3).fit_predict(X2),
    REGRESSION_CLUSTER_RESULTS,
    supervised=True
)
tryClusterer(
    "Агломеративная/4 класса/3 признака",
    reg,
    AgglomerativeClustering(n_clusters=4).fit_predict(X2),
    REGRESSION_CLUSTER_RESULTS,
    supervised=True
)
# Используем предварительное масштабирование данных, также метод агломеративной кластеризации
tryClusterer(
    "Агломеративная/2 класса/масштабирование/3 признака",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', AgglomerativeClustering(n_clusters=2))
        ]
    ).fit_predict(X2),
    REGRESSION_CLUSTER_RESULTS,
    supervised=True
)
tryClusterer(
    "Агломеративная/3 класса/масштабирование/3 признака",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', AgglomerativeClustering(n_clusters=4))
        ]
    ).fit_predict(X2),
    REGRESSION_CLUSTER_RESULTS,
    supervised=True
)
tryClusterer(
    "Агломеративная/3 класса/масштабирование/3 признака",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', AgglomerativeClustering(n_clusters=4))
        ]
    ).fit_predict(X2),
    REGRESSION_CLUSTER_RESULTS,
    supervised=True
)
# Агломеративная кластеризация с пороговым значением размера кластера
tryClusterer(
    "Агломеративная/Порог 25/масштабирование/3 признака",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', AgglomerativeClustering(n_clusters=None, distance_threshold=25))
        ]
    ).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)
tryClusterer(
    "Агломеративная/Порог 50/масштабирование/3 признака",
    reg,
    Pipeline(
        [
            ('scale', StandardScaler()),
            ('cluster', AgglomerativeClustering(n_clusters=None, distance_threshold=50))
        ]
    ).fit_predict(X),
    REGRESSION_CLUSTER_RESULTS
)

# %%
# Смотрим таблицу результатов
REGRESSION_CLUSTER_RESULTS.sort_values(["С учителем", "Количество кластеров"])
# Out:
#                                                    С учителем  \
# K-средних/2 класса                                      False
# K-средних/2 класса/масштабирование                      False
# Агломеративная/2 класса                                 False
# Агломеративная/2 класса/масштабирование                 False
# K-средних/3 класса                                      False
# Агломеративная/3 класса                                 False
# K-средних/4 класса                                      False
# K-средних/3 класса/масштабирование                      False
# Агломеративная/4 класса                                 False
# Агломеративная/3 класса/масштабирование                 False
# Агломеративная/Порог 50/масштабирование                 False
# Агломеративная/Порог 50/масштабирование/3 признака      False
# Агломеративная/Порог 25/масштабирование                 False
# Агломеративная/Порог 25/масштабирование/3 признака      False
# Идеальный вариант                                        True
# Идеальный вариант для предсказанного качества            True
# K-средних/2 класса/3 признака                            True
# K-средних/2 класса/масштабирование/3 признака            True
# Агломеративная/2 класса/3 признака                       True
# Агломеративная/2 класса/масштабирование/3 признака       True
# K-средних/3 класса/3 признака                            True
# Агломеративная/3 класса/3 признака                       True
# K-средних/4 класса/3 признака                            True
# K-средних/3 класса/масштабирование/3 признака            True
# Агломеративная/4 класса/3 признака                       True
# Агломеративная/3 класса/масштабирование/3 признака       True
#
#                                                    Количество кластеров  \
# K-средних/2 класса                                                    2
# K-средних/2 класса/масштабирование                                    2
# Агломеративная/2 класса                                               2
# Агломеративная/2 класса/масштабирование                               2
# K-средних/3 класса                                                    3
# Агломеративная/3 класса                                               3
# K-средних/4 класса                                                    4
# K-средних/3 класса/масштабирование                                    4
# Агломеративная/4 класса                                               4
# Агломеративная/3 класса/масштабирование                               4
# Агломеративная/Порог 50/масштабирование                               6
# Агломеративная/Порог 50/масштабирование/3 признака                    6
# Агломеративная/Порог 25/масштабирование                              25
# Агломеративная/Порог 25/масштабирование/3 признака                   25
# Идеальный вариант                                                     2
# Идеальный вариант для предсказанного качества                         2
# K-средних/2 класса/3 признака                                         2
# K-средних/2 класса/масштабирование/3 признака                         2
# Агломеративная/2 класса/3 признака                                    2
# Агломеративная/2 класса/масштабирование/3 признака                    2
# K-средних/3 класса/3 признака                                         3
# Агломеративная/3 класса/3 признака                                    3
# K-средних/4 класса/3 признака                                         4
# K-средних/3 класса/масштабирование/3 признака                         4
# Агломеративная/4 класса/3 признака                                    4
# Агломеративная/3 класса/масштабирование/3 признака                    4
#
#                                                    Максимальный размер кластера  \
# K-средних/2 класса                                                         2800
# K-средних/2 класса/масштабирование                                         2937
# Агломеративная/2 класса                                                    3014
# Агломеративная/2 класса/масштабирование                                    2933
# K-средних/3 класса                                                         1976
# Агломеративная/3 класса                                                    1884
# K-средних/4 класса                                                         1714
# K-средних/3 класса/масштабирование                                         1697
# Агломеративная/4 класса                                                    1577
# Агломеративная/3 класса/масштабирование                                    1892
# Агломеративная/Порог 50/масштабирование                                    1041
# Агломеративная/Порог 50/масштабирование/3 признака                         1041
# Агломеративная/Порог 25/масштабирование                                     524
# Агломеративная/Порог 25/масштабирование/3 признака                          524
# Идеальный вариант                                                          3258
# Идеальный вариант для предсказанного качества                              2449
# K-средних/2 класса/3 признака                                              3025
# K-средних/2 класса/масштабирование/3 признака                              2495
# Агломеративная/2 класса/3 признака                                         3350
# Агломеративная/2 класса/масштабирование/3 признака                         2686
# K-средних/3 класса/3 признака                                              2178
# Агломеративная/3 класса/3 признака                                         1722
# K-средних/4 класса/3 признака                                              1858
# K-средних/3 класса/масштабирование/3 признака                              1790
# Агломеративная/4 класса/3 признака                                         1722
# Агломеративная/3 класса/масштабирование/3 признака                         1543
#
#                                                    Минимальный размер кластера  \
# K-средних/2 класса                                                        2098
# K-средних/2 класса/масштабирование                                        1961
# Агломеративная/2 класса                                                   1884
# Агломеративная/2 класса/масштабирование                                   1965
# K-средних/3 класса                                                        1124
# Агломеративная/3 класса                                                   1437
# K-средних/4 класса                                                         762
# K-средних/3 класса/масштабирование                                         107
# Агломеративная/4 класса                                                    670
# Агломеративная/3 класса/масштабирование                                     80
# Агломеративная/Порог 50/масштабирование                                     80
# Агломеративная/Порог 50/масштабирование/3 признака                          80
# Агломеративная/Порог 25/масштабирование                                      1
# Агломеративная/Порог 25/масштабирование/3 признака                           1
# Идеальный вариант                                                         1640
# Идеальный вариант для предсказанного качества                             2449
# K-средних/2 класса/3 признака                                             1873
# K-средних/2 класса/масштабирование/3 признака                             2403
# Агломеративная/2 класса/3 признака                                        1548
# Агломеративная/2 класса/масштабирование/3 признака                        2212
# K-средних/3 класса/3 признака                                             1021
# Агломеративная/3 класса/3 признака                                        1548
# K-средних/4 класса/3 признака                                              425
# K-средних/3 класса/масштабирование/3 признака                              443
# Агломеративная/4 класса/3 признака                                         199
# Агломеративная/3 класса/масштабирование/3 признака                        1007
#
#                                                    Максимальное среднее качество по кластеру  \
# K-средних/2 класса                                                                   6.00964
# K-средних/2 класса/масштабирование                                                   6.06129
# Агломеративная/2 класса                                                              6.00531
# Агломеративная/2 класса/масштабирование                                              5.98807
# K-средних/3 класса                                                                   6.00278
# Агломеративная/3 класса                                                              6.03479
# K-средних/4 класса                                                                   6.04551
# K-средних/3 класса/масштабирование                                                   6.14251
# Агломеративная/4 класса                                                              6.03479
# Агломеративная/3 класса/масштабирование                                              6.02484
# Агломеративная/Порог 50/масштабирование                                              6.31431
# Агломеративная/Порог 50/масштабирование/3 признака                                   6.31431
# Агломеративная/Порог 25/масштабирование                                              6.64744
# Агломеративная/Порог 25/масштабирование/3 признака                                   6.64744
# Идеальный вариант                                                                    6.38214
# Идеальный вариант для предсказанного качества                                        6.32666
# K-средних/2 класса/3 признака                                                        5.89388
# K-средних/2 класса/масштабирование/3 признака                                        6.03727
# Агломеративная/2 класса/3 признака                                                   5.91343
# Агломеративная/2 класса/масштабирование/3 признака                                   6.14296
# K-средних/3 класса/3 признака                                                        6.03535
# Агломеративная/3 класса/3 признака                                                   6.05517
# K-средних/4 класса/3 признака                                                        6.05167
# K-средних/3 класса/масштабирование/3 признака                                        6.39862
# Агломеративная/4 класса/3 признака                                                   6.05517
# Агломеративная/3 класса/масштабирование/3 признака                                   6.40245
#
#                                                    Минимальное среднее качество по кластеру  \
# K-средних/2 класса                                                                   5.7021
# K-средних/2 класса/масштабирование                                                  5.60326
# Агломеративная/2 класса                                                              5.6741
# Агломеративная/2 класса/масштабирование                                             5.71349
# K-средних/3 класса                                                                  5.55605
# Агломеративная/3 класса                                                              5.6741
# K-средних/4 класса                                                                  5.54593
# K-средних/3 класса/масштабирование                                                  5.48598
# Агломеративная/4 класса                                                             5.52388
# Агломеративная/3 класса/масштабирование                                              5.4375
# Агломеративная/Порог 50/масштабирование                                              5.4375
# Агломеративная/Порог 50/масштабирование/3 признака                                   5.4375
# Агломеративная/Порог 25/масштабирование                                             5.13462
# Агломеративная/Порог 25/масштабирование/3 признака                                  5.13462
# Идеальный вариант                                                                   4.87622
# Идеальный вариант для предсказанного качества                                       5.42915
# K-средних/2 класса/3 признака                                                       5.85211
# K-средних/2 класса/масштабирование/3 признака                                       5.71244
# Агломеративная/2 класса/3 признака                                                  5.80103
# Агломеративная/2 класса/масштабирование/3 признака                                  5.55606
# K-средних/3 класса/3 признака                                                       5.73849
# Агломеративная/3 класса/3 признака                                                  5.76351
# K-средних/4 класса/3 признака                                                       5.65176
# K-средних/3 класса/масштабирование/3 признака                                       5.38375
# Агломеративная/4 класса/3 признака                                                  5.67337
# Агломеративная/3 класса/масштабирование/3 признака                                  5.33069
#
#                                                    Максимальное предсказанное среднее качество по кластеру  \
# K-средних/2 класса                                                                            5.99589
# K-средних/2 класса/масштабирование                                                            6.04886
# Агломеративная/2 класса                                                                        5.9845
# Агломеративная/2 класса/масштабирование                                                       6.00238
# K-средних/3 класса                                                                            6.01782
# Агломеративная/3 класса                                                                       6.04688
# K-средних/4 класса                                                                            6.01909
# K-средних/3 класса/масштабирование                                                            6.05798
# Агломеративная/4 класса                                                                       6.04688
# Агломеративная/3 класса/масштабирование                                                       6.01109
# Агломеративная/Порог 50/масштабирование                                                       6.26894
# Агломеративная/Порог 50/масштабирование/3 признака                                            6.26894
# Агломеративная/Порог 25/масштабирование                                                       6.41125
# Агломеративная/Порог 25/масштабирование/3 признака                                            6.41125
# Идеальный вариант                                                                             6.01637
# Идеальный вариант для предсказанного качества                                                 6.19324
# K-средних/2 класса/3 признака                                                                 5.91642
# K-средних/2 класса/масштабирование/3 признака                                                 6.06032
# Агломеративная/2 класса/3 признака                                                            5.92578
# Агломеративная/2 класса/масштабирование/3 признака                                            6.10533
# K-средних/3 класса/3 признака                                                                 5.94433
# Агломеративная/3 класса/3 признака                                                            5.96851
# K-средних/4 класса/3 признака                                                                 5.96899
# K-средних/3 класса/масштабирование/3 признака                                                 6.34246
# Агломеративная/4 класса/3 признака                                                            5.96851
# Агломеративная/3 класса/масштабирование/3 признака                                             6.3493
#
#                                                    Минимальное предсказанное среднее качество по кластеру
# K-средних/2 класса                                                                            5.71618
# K-средних/2 класса/масштабирование                                                            5.61731
# Агломеративная/2 класса                                                                       5.70264
# Агломеративная/2 класса/масштабирование                                                       5.68756
# K-средних/3 класса                                                                            5.62889
# Агломеративная/3 класса                                                                       5.70264
# K-средних/4 класса                                                                            5.59413
# K-средних/3 класса/масштабирование                                                            5.50677
# Агломеративная/4 класса                                                                       5.57975
# Агломеративная/3 класса/масштабирование                                                       5.49519
# Агломеративная/Порог 50/масштабирование                                                       5.49519
# Агломеративная/Порог 50/масштабирование/3 признака                                            5.49519
# Агломеративная/Порог 25/масштабирование                                                       5.35121
# Агломеративная/Порог 25/масштабирование/3 признака                                            5.35121
# Идеальный вариант                                                                             5.59739
# Идеальный вариант для предсказанного качества                                                 5.55892
# K-средних/2 класса/3 признака                                                                 5.81094
# K-средних/2 класса/масштабирование/3 признака                                                 5.68479
# Агломеративная/2 класса/3 признака                                                            5.76853
# Агломеративная/2 класса/масштабирование/3 признака                                            5.59771
# K-средних/3 класса/3 признака                                                                  5.7336
# Агломеративная/3 класса/3 признака                                                            5.76853
# K-средних/4 класса/3 признака                                                                 5.69959
# K-средних/3 класса/масштабирование/3 признака                                                 5.53248
# Агломеративная/4 класса/3 признака                                                            5.71183
# Агломеративная/3 класса/масштабирование/3 признака                                            5.46505

# %%
# Метрика качества кластеризации - берем разность между средним качеством по
# кластеру с максимальным и минимальным средним качеством, делим на такую
# же разницу для идеального разделения. Эта метрика равна 1 для кластеров,
# идеально отделяющих хорошие вина от плохих и 0 для кластеров, в каждом
# из которых среднее качество вина одинаково. Заметим, что сравнивать по
# этой метрике можно только алгоритмы с одинаковым числом кластеров, так
# как большое число маленьких кластеров, естественно, дает более мелкие
# кластеры
REGRESSION_CLUSTER_RESULTS[
    "Качество кластеризации для истинного качества вина"
] = (REGRESSION_CLUSTER_RESULTS[
    "Максимальное среднее качество по кластеру"
] - REGRESSION_CLUSTER_RESULTS[
    "Минимальное среднее качество по кластеру"
]) / (REGRESSION_CLUSTER_RESULTS.loc[
    "Идеальный вариант", "Максимальное среднее качество по кластеру"
] - REGRESSION_CLUSTER_RESULTS.loc[
    "Идеальный вариант", "Минимальное среднее качество по кластеру"
])

REGRESSION_CLUSTER_RESULTS[
    "Качество кластеризации для предсказанного качества вина"
] = (REGRESSION_CLUSTER_RESULTS[
    "Максимальное предсказанное среднее качество по кластеру"
] - REGRESSION_CLUSTER_RESULTS[
    "Минимальное предсказанное среднее качество по кластеру"
]) / (REGRESSION_CLUSTER_RESULTS.loc[
    "Идеальный вариант для предсказанного качества", "Максимальное предсказанное среднее качество по кластеру"
] - REGRESSION_CLUSTER_RESULTS.loc[
    "Идеальный вариант для предсказанного качества", "Минимальное предсказанное среднее качество по кластеру"
])

# %%
# Смотрим таблицу результатов. При этом группируем результаты по признаку обучения
# с учителем, так как нельзя сравнивать результаты, полученные с учителем и без,
# и по количеству кластеров
REGRESSION_CLUSTER_RESULTS.sort_values(
    ["С учителем", "Количество кластеров", "Качество кластеризации для истинного качества вина"]
)
# Out:
#                                                    С учителем  \
# Агломеративная/2 класса/масштабирование                 False
# K-средних/2 класса                                      False
# Агломеративная/2 класса                                 False
# K-средних/2 класса/масштабирование                      False
# Агломеративная/3 класса                                 False
# K-средних/3 класса                                      False
# K-средних/4 класса                                      False
# Агломеративная/4 класса                                 False
# Агломеративная/3 класса/масштабирование                 False
# K-средних/3 класса/масштабирование                      False
# Агломеративная/Порог 50/масштабирование                 False
# Агломеративная/Порог 50/масштабирование/3 признака      False
# Агломеративная/Порог 25/масштабирование                 False
# Агломеративная/Порог 25/масштабирование/3 признака      False
# K-средних/2 класса/3 признака                            True
# Агломеративная/2 класса/3 признака                       True
# K-средних/2 класса/масштабирование/3 признака            True
# Агломеративная/2 класса/масштабирование/3 признака       True
# Идеальный вариант для предсказанного качества            True
# Идеальный вариант                                        True
# Агломеративная/3 класса/3 признака                       True
# K-средних/3 класса/3 признака                            True
# Агломеративная/4 класса/3 признака                       True
# K-средних/4 класса/3 признака                            True
# K-средних/3 класса/масштабирование/3 признака            True
# Агломеративная/3 класса/масштабирование/3 признака       True
#
#                                                    Количество кластеров  \
# Агломеративная/2 класса/масштабирование                               2
# K-средних/2 класса                                                    2
# Агломеративная/2 класса                                               2
# K-средних/2 класса/масштабирование                                    2
# Агломеративная/3 класса                                               3
# K-средних/3 класса                                                    3
# K-средних/4 класса                                                    4
# Агломеративная/4 класса                                               4
# Агломеративная/3 класса/масштабирование                               4
# K-средних/3 класса/масштабирование                                    4
# Агломеративная/Порог 50/масштабирование                               6
# Агломеративная/Порог 50/масштабирование/3 признака                    6
# Агломеративная/Порог 25/масштабирование                              25
# Агломеративная/Порог 25/масштабирование/3 признака                   25
# K-средних/2 класса/3 признака                                         2
# Агломеративная/2 класса/3 признака                                    2
# K-средних/2 класса/масштабирование/3 признака                         2
# Агломеративная/2 класса/масштабирование/3 признака                    2
# Идеальный вариант для предсказанного качества                         2
# Идеальный вариант                                                     2
# Агломеративная/3 класса/3 признака                                    3
# K-средних/3 класса/3 признака                                         3
# Агломеративная/4 класса/3 признака                                    4
# K-средних/4 класса/3 признака                                         4
# K-средних/3 класса/масштабирование/3 признака                         4
# Агломеративная/3 класса/масштабирование/3 признака                    4
#
#                                                    Максимальный размер кластера  \
# Агломеративная/2 класса/масштабирование                                    2933
# K-средних/2 класса                                                         2800
# Агломеративная/2 класса                                                    3014
# K-средних/2 класса/масштабирование                                         2937
# Агломеративная/3 класса                                                    1884
# K-средних/3 класса                                                         1976
# K-средних/4 класса                                                         1714
# Агломеративная/4 класса                                                    1577
# Агломеративная/3 класса/масштабирование                                    1892
# K-средних/3 класса/масштабирование                                         1697
# Агломеративная/Порог 50/масштабирование                                    1041
# Агломеративная/Порог 50/масштабирование/3 признака                         1041
# Агломеративная/Порог 25/масштабирование                                     524
# Агломеративная/Порог 25/масштабирование/3 признака                          524
# K-средних/2 класса/3 признака                                              3025
# Агломеративная/2 класса/3 признака                                         3350
# K-средних/2 класса/масштабирование/3 признака                              2495
# Агломеративная/2 класса/масштабирование/3 признака                         2686
# Идеальный вариант для предсказанного качества                              2449
# Идеальный вариант                                                          3258
# Агломеративная/3 класса/3 признака                                         1722
# K-средних/3 класса/3 признака                                              2178
# Агломеративная/4 класса/3 признака                                         1722
# K-средних/4 класса/3 признака                                              1858
# K-средних/3 класса/масштабирование/3 признака                              1790
# Агломеративная/3 класса/масштабирование/3 признака                         1543
#
#                                                    Минимальный размер кластера  \
# Агломеративная/2 класса/масштабирование                                   1965
# K-средних/2 класса                                                        2098
# Агломеративная/2 класса                                                   1884
# K-средних/2 класса/масштабирование                                        1961
# Агломеративная/3 класса                                                   1437
# K-средних/3 класса                                                        1124
# K-средних/4 класса                                                         762
# Агломеративная/4 класса                                                    670
# Агломеративная/3 класса/масштабирование                                     80
# K-средних/3 класса/масштабирование                                         107
# Агломеративная/Порог 50/масштабирование                                     80
# Агломеративная/Порог 50/масштабирование/3 признака                          80
# Агломеративная/Порог 25/масштабирование                                      1
# Агломеративная/Порог 25/масштабирование/3 признака                           1
# K-средних/2 класса/3 признака                                             1873
# Агломеративная/2 класса/3 признака                                        1548
# K-средних/2 класса/масштабирование/3 признака                             2403
# Агломеративная/2 класса/масштабирование/3 признака                        2212
# Идеальный вариант для предсказанного качества                             2449
# Идеальный вариант                                                         1640
# Агломеративная/3 класса/3 признака                                        1548
# K-средних/3 класса/3 признака                                             1021
# Агломеративная/4 класса/3 признака                                         199
# K-средних/4 класса/3 признака                                              425
# K-средних/3 класса/масштабирование/3 признака                              443
# Агломеративная/3 класса/масштабирование/3 признака                        1007
#
#                                                    Максимальное среднее качество по кластеру  \
# Агломеративная/2 класса/масштабирование                                              5.98807
# K-средних/2 класса                                                                   6.00964
# Агломеративная/2 класса                                                              6.00531
# K-средних/2 класса/масштабирование                                                   6.06129
# Агломеративная/3 класса                                                              6.03479
# K-средних/3 класса                                                                   6.00278
# K-средних/4 класса                                                                   6.04551
# Агломеративная/4 класса                                                              6.03479
# Агломеративная/3 класса/масштабирование                                              6.02484
# K-средних/3 класса/масштабирование                                                   6.14251
# Агломеративная/Порог 50/масштабирование                                              6.31431
# Агломеративная/Порог 50/масштабирование/3 признака                                   6.31431
# Агломеративная/Порог 25/масштабирование                                              6.64744
# Агломеративная/Порог 25/масштабирование/3 признака                                   6.64744
# K-средних/2 класса/3 признака                                                        5.89388
# Агломеративная/2 класса/3 признака                                                   5.91343
# K-средних/2 класса/масштабирование/3 признака                                        6.03727
# Агломеративная/2 класса/масштабирование/3 признака                                   6.14296
# Идеальный вариант для предсказанного качества                                        6.32666
# Идеальный вариант                                                                    6.38214
# Агломеративная/3 класса/3 признака                                                   6.05517
# K-средних/3 класса/3 признака                                                        6.03535
# Агломеративная/4 класса/3 признака                                                   6.05517
# K-средних/4 класса/3 признака                                                        6.05167
# K-средних/3 класса/масштабирование/3 признака                                        6.39862
# Агломеративная/3 класса/масштабирование/3 признака                                   6.40245
#
#                                                    Минимальное среднее качество по кластеру  \
# Агломеративная/2 класса/масштабирование                                             5.71349
# K-средних/2 класса                                                                   5.7021
# Агломеративная/2 класса                                                              5.6741
# K-средних/2 класса/масштабирование                                                  5.60326
# Агломеративная/3 класса                                                              5.6741
# K-средних/3 класса                                                                  5.55605
# K-средних/4 класса                                                                  5.54593
# Агломеративная/4 класса                                                             5.52388
# Агломеративная/3 класса/масштабирование                                              5.4375
# K-средних/3 класса/масштабирование                                                  5.48598
# Агломеративная/Порог 50/масштабирование                                              5.4375
# Агломеративная/Порог 50/масштабирование/3 признака                                   5.4375
# Агломеративная/Порог 25/масштабирование                                             5.13462
# Агломеративная/Порог 25/масштабирование/3 признака                                  5.13462
# K-средних/2 класса/3 признака                                                       5.85211
# Агломеративная/2 класса/3 признака                                                  5.80103
# K-средних/2 класса/масштабирование/3 признака                                       5.71244
# Агломеративная/2 класса/масштабирование/3 признака                                  5.55606
# Идеальный вариант для предсказанного качества                                       5.42915
# Идеальный вариант                                                                   4.87622
# Агломеративная/3 класса/3 признака                                                  5.76351
# K-средних/3 класса/3 признака                                                       5.73849
# Агломеративная/4 класса/3 признака                                                  5.67337
# K-средних/4 класса/3 признака                                                       5.65176
# K-средних/3 класса/масштабирование/3 признака                                       5.38375
# Агломеративная/3 класса/масштабирование/3 признака                                  5.33069
#
#                                                    Максимальное предсказанное среднее качество по кластеру  \
# Агломеративная/2 класса/масштабирование                                                       6.00238
# K-средних/2 класса                                                                            5.99589
# Агломеративная/2 класса                                                                        5.9845
# K-средних/2 класса/масштабирование                                                            6.04886
# Агломеративная/3 класса                                                                       6.04688
# K-средних/3 класса                                                                            6.01782
# K-средних/4 класса                                                                            6.01909
# Агломеративная/4 класса                                                                       6.04688
# Агломеративная/3 класса/масштабирование                                                       6.01109
# K-средних/3 класса/масштабирование                                                            6.05798
# Агломеративная/Порог 50/масштабирование                                                       6.26894
# Агломеративная/Порог 50/масштабирование/3 признака                                            6.26894
# Агломеративная/Порог 25/масштабирование                                                       6.41125
# Агломеративная/Порог 25/масштабирование/3 признака                                            6.41125
# K-средних/2 класса/3 признака                                                                 5.91642
# Агломеративная/2 класса/3 признака                                                            5.92578
# K-средних/2 класса/масштабирование/3 признака                                                 6.06032
# Агломеративная/2 класса/масштабирование/3 признака                                            6.10533
# Идеальный вариант для предсказанного качества                                                 6.19324
# Идеальный вариант                                                                             6.01637
# Агломеративная/3 класса/3 признака                                                            5.96851
# K-средних/3 класса/3 признака                                                                 5.94433
# Агломеративная/4 класса/3 признака                                                            5.96851
# K-средних/4 класса/3 признака                                                                 5.96899
# K-средних/3 класса/масштабирование/3 признака                                                 6.34246
# Агломеративная/3 класса/масштабирование/3 признака                                             6.3493
#
#                                                    Минимальное предсказанное среднее качество по кластеру  \
# Агломеративная/2 класса/масштабирование                                                       5.68756
# K-средних/2 класса                                                                            5.71618
# Агломеративная/2 класса                                                                       5.70264
# K-средних/2 класса/масштабирование                                                            5.61731
# Агломеративная/3 класса                                                                       5.70264
# K-средних/3 класса                                                                            5.62889
# K-средних/4 класса                                                                            5.59413
# Агломеративная/4 класса                                                                       5.57975
# Агломеративная/3 класса/масштабирование                                                       5.49519
# K-средних/3 класса/масштабирование                                                            5.50677
# Агломеративная/Порог 50/масштабирование                                                       5.49519
# Агломеративная/Порог 50/масштабирование/3 признака                                            5.49519
# Агломеративная/Порог 25/масштабирование                                                       5.35121
# Агломеративная/Порог 25/масштабирование/3 признака                                            5.35121
# K-средних/2 класса/3 признака                                                                 5.81094
# Агломеративная/2 класса/3 признака                                                            5.76853
# K-средних/2 класса/масштабирование/3 признака                                                 5.68479
# Агломеративная/2 класса/масштабирование/3 признака                                            5.59771
# Идеальный вариант для предсказанного качества                                                 5.55892
# Идеальный вариант                                                                             5.59739
# Агломеративная/3 класса/3 признака                                                            5.76853
# K-средних/3 класса/3 признака                                                                  5.7336
# Агломеративная/4 класса/3 признака                                                            5.71183
# K-средних/4 класса/3 признака                                                                 5.69959
# K-средних/3 класса/масштабирование/3 признака                                                 5.53248
# Агломеративная/3 класса/масштабирование/3 признака                                            5.46505
#
#                                                    Качество кластеризации для истинного качества вина  \
# Агломеративная/2 класса/масштабирование                                                      0.182335
# K-средних/2 класса                                                                           0.204225
# Агломеративная/2 класса                                                                       0.21994
# K-средних/2 класса/масштабирование                                                           0.304149
# Агломеративная/3 класса                                                                       0.23952
# K-средних/3 класса                                                                           0.296651
# K-средних/4 класса                                                                           0.331742
# Агломеративная/4 класса                                                                      0.339271
# Агломеративная/3 класса/масштабирование                                                      0.390023
# K-средних/3 класса/масштабирование                                                           0.435964
# Агломеративная/Порог 50/масштабирование                                                      0.582246
# Агломеративная/Порог 50/масштабирование/3 признака                                           0.582246
# Агломеративная/Порог 25/масштабирование                                                       1.00458
# Агломеративная/Порог 25/масштабирование/3 признака                                            1.00458
# K-средних/2 класса/3 признака                                                               0.0277408
# Агломеративная/2 класса/3 признака                                                          0.0746384
# K-средних/2 класса/масштабирование/3 признака                                                0.215704
# Агломеративная/2 класса/масштабирование/3 признака                                           0.389733
# Идеальный вариант для предсказанного качества                                                0.595989
# Идеальный вариант                                                                                   1
# Агломеративная/3 класса/3 признака                                                           0.193673
# K-средних/3 класса/3 признака                                                                 0.19713
# Агломеративная/4 класса/3 признака                                                           0.253534
# K-средних/4 класса/3 признака                                                                0.265555
# K-средних/3 класса/масштабирование/3 признака                                                0.673922
# Агломеративная/3 класса/масштабирование/3 признака                                           0.711702
#
#                                                    Качество кластеризации для предсказанного качества вина
# Агломеративная/2 класса/масштабирование                                                      0.496319
# K-средних/2 класса                                                                           0.440956
# Агломеративная/2 класса                                                                      0.444356
# K-средних/2 класса/масштабирование                                                           0.680335
# Агломеративная/3 класса                                                                      0.542703
# K-средних/3 класса                                                                           0.613138
# K-средних/4 класса                                                                            0.66994
# Агломеративная/4 класса                                                                      0.736438
# Агломеративная/3 класса/масштабирование                                                      0.813314
# K-средних/3 класса/масштабирование                                                           0.868974
# Агломеративная/Порог 50/масштабирование                                                       1.21982
# Агломеративная/Порог 50/масштабирование/3 признака                                            1.21982
# Агломеративная/Порог 25/масштабирование                                                       1.67114
# Агломеративная/Порог 25/масштабирование/3 признака                                            1.67114
# K-средних/2 класса/3 признака                                                                0.166291
# Агломеративная/2 класса/3 признака                                                             0.2479
# K-средних/2 класса/масштабирование/3 признака                                                0.592016
# Агломеративная/2 класса/масштабирование/3 признака                                            0.80026
# Идеальный вариант для предсказанного качества                                                       1
# Идеальный вариант                                                                            0.660513
# Агломеративная/3 класса/3 признака                                                           0.315258
# K-средних/3 класса/3 признака                                                                 0.33221
# Агломеративная/4 класса/3 признака                                                           0.404651
# K-средних/4 класса/3 признака                                                                0.424714
# K-средних/3 класса/масштабирование/3 признака                                                 1.27693
# Агломеративная/3 класса/масштабирование/3 признака                                            1.39402

# %%
print("""
Выводы
------
* Среди моделей обучения без учителя, разделяющих на 2 кластера, лучшая имеет качество 0.3,
  это модель K-средних с приведением всех признаков к единому масштабу. Заметим, что предсказаннае
  случайным лесом значения качества вина эта модель предсказывает намного лучше - с качеством
  0.68. По этой метрике она также лучшая

* Из моделей кластеризации, обученных по трем специально отобранным признакам, лучшей является
  агломеративная кластеризация, также с приведением признаков к единому масштабу. Она имеет качество
  0.38 для разделения по истинному качеству вина и 0.8 для разделения по предсказанному случайным
  лесом качеству вина.

* Таким образом, подтверждается гипотеза о том, что измерение качества вина имеет субъективную
  компоненту, и предсказанию моделями машинного обучения поддается плохо. Ни одна из моделей регрессии
  не может достичь коэффициента детерминации хотя бы 0.5 при предсказании истинного качества вина.
  При этом значения качества, полученные моделями регрессии, могут быть кластеризованы существенно
  чище, чем истинные значения качества вина. Влияние отбора трех наиболее важных признаков
  на чистоту кластеров менее существенно
""")
# Out:
# Выводы
# ------
# * Среди моделей обучения без учителя, разделяющих на 2 кластера, лучшая имеет качество 0.3,
#   это модель K-средних с приведением всех признаков к единому масштабу. Заметим, что предсказаннае
#   случайным лесом значения качества вина эта модель предсказывает намного лучше - с качеством
#   0.68. По этой метрике она также лучшая
#
# * Из моделей кластеризации, обученных по трем специально отобранным признакам, лучшей является
#   агломеративная кластеризация, также с приведением признаков к единому масштабу. Она имеет качество
#   0.38 для разделения по истинному качеству вина и 0.8 для разделения по предсказанному случайным
#   лесом качеству вина.
#
# * Таким образом, подтверждается гипотеза о том, что измерение качества вина имеет субъективную
#   компоненту, и предсказанию моделями машинного обучения поддается плохо. Ни одна из моделей регрессии
#   не может достичь коэффициента детерминации хотя бы 0.5 при предсказании истинного качества вина.
#   При этом значения качества, полученные моделями регрессии, могут быть кластеризованы существенно
#   чище, чем истинные значения качества вина. Влияние отбора трех наиболее важных признаков
#   на чистоту кластеров менее существенно
